# %% [markdown]
# # Introduction

# %% [markdown]
# This model was built based on a Keras (Chollet, F. & others, 2015. Keras. Available at: https://github.com/fchollet/keras.) demonstration on how to classify speakers using Fast Fourier Transform (FFT) and a 1D convolutional neural network model audio classification.
#
# It shows the following:
#
# How to use tf.data to load, preprocess and feed audio streams into a model
# How to create a 1D convolutional network with residual connections for audio classification.
#
# Our process:
#
# We prepare a dataset of speech samples from different speakers, with the speaker as label.
# We add background noise to these samples to augment our data.
# We take the FFT of these samples.
# We train a 1D convnet to predict the correct speaker given a noisy FFT speech sample.
#
# Note:
#
# The noise samples in the dataset were standardized to a sampling rate of 16000 Hz before using the code in this example. In order to do this, we resampled using audacity.
#
# Chollet, F. & others, 2015. Keras. Available at: https://github.com/fchollet/keras.
#
# Background sounds taken from https://www.kaggle.com/kongaevans/speaker-recognition-dataset/download

# %%
import os
import shutil
import numpy as np

import tensorflow as tf
from tensorflow import keras
import pydot
import matplotlib

from pathlib import Path
from IPython.display import display, Audio

# The database was built using 7 minute of speach from each member of the group
DATASET_ROOT = os.path.join(os.path.expanduser("~"), "Documents/Github/voice-classifier/Data")

# The folders in which we will put the audio samples and the noise samples
AUDIO_SUBFOLDER = "audio"
NOISE_SUBFOLDER = "noise"

DATASET_AUDIO_PATH = os.path.join(DATASET_ROOT, AUDIO_SUBFOLDER)
DATASET_NOISE_PATH = os.path.join(DATASET_ROOT, NOISE_SUBFOLDER)

# Percentage of samples to use for validation
VALID_SPLIT = 0.1

# Seed to use when shuffling the dataset and the noise
SHUFFLE_SEED = 43

# The sampling rate to use.
# This is the one used in all of the audio samples.
# We will resample all of the noise to this sampling rate.
# This will also be the output size of the audio wave samples
# (since all samples are of 1 second long)
SAMPLING_RATE = 16000

# The factor to multiply the noise with according to:
#   noisy_sample = sample + noise * prop * scale
#      where prop = sample_amplitude / noise_amplitude
SCALE = 0.5

BATCH_SIZE = 128
EPOCHS = 100

# %% [markdown]
# # Data preparation
#
# ### The dataset is composed of 7 folders, divided into 2 groups:
#
# - Speech samples, with 5 folders, one for each member in our group. Each folder contains audio files for that speaker, each 1 second long and sampled at 16000 Hz.
# - Background noise samples, with 2 folders and a total of 6 files. These files are longer than 1 second (and originally not sampled at 16000 Hz, but we will resample them to 16000 Hz). We will use those 6 files to create 354 1-second-long noise samples to be used for training.
#
# ### Let's sort these 2 categories into 2 folders:
#
# - An audio folder which will contain all the per-speaker speech sample folders
# - A noise folder which will contain all the noise samples
#
# Before sorting the audio and noise categories into 2 folders,

# %% [markdown]
# main_directory/
#
#     ...speaker_juan/
#     ...speaker_hom/
#     ...speaker_mike/
#     ...speaker_ed/
#     ...speaker_dan/
#     ...other/
#     ..._background_noise_/

# %% [markdown]
# After sorting, we end up with the following structure:
#
# main_directory/
#
#     ...audio/
#     ......speaker_juan/
#     ......speaker_hom/
#     ......speaker_mike/
#     ......speaker_ed/
#     ......speaker_dan/
#     ...noise/
#     ......other/
#     ......_background_noise_/

# %%
# If folder `audio`, does not exist, create it, otherwise do nothing
if os.path.exists(DATASET_AUDIO_PATH) is False:
    os.makedirs(DATASET_AUDIO_PATH)

# If folder `noise`, does not exist, create it, otherwise do nothing
if os.path.exists(DATASET_NOISE_PATH) is False:
    os.makedirs(DATASET_NOISE_PATH)

for folder in os.listdir(DATASET_ROOT):
    if os.path.isdir(os.path.join(DATASET_ROOT, folder)):
        if folder in [AUDIO_SUBFOLDER, NOISE_SUBFOLDER]:
            # If folder is `audio` or `noise`, do nothing
            continue
        elif folder in ["other", "_background_noise_"]:
            # If folder is one of the folders that contains noise samples,
            # move it to the `noise` folder
            shutil.move(
                os.path.join(DATASET_ROOT, folder),
                os.path.join(DATASET_NOISE_PATH, folder),
            )
        else:
            # Otherwise, it should be a speaker folder, then move it to
            # `audio` folder
            shutil.move(
                os.path.join(DATASET_ROOT, folder),
                os.path.join(DATASET_AUDIO_PATH, folder),
            )

# %% [markdown]
# # Noise preparation
# In this section:
#
# - We load all noise samples (which should have been resampled to 16000)
# - We split those noise samples to chuncks of 16000 samples which correspond to 1 second duration each

# %%
# Get the list of all noise files
noise_paths = []
for subdir in os.listdir(DATASET_NOISE_PATH):
    subdir_path = Path(DATASET_NOISE_PATH) / subdir
    if os.path.isdir(subdir_path):
        noise_paths += [
            os.path.join(subdir_path, filepath)
            for filepath in os.listdir(subdir_path)
            if filepath.endswith(".wav")
        ]

print(
    "Found {} files belonging to {} directories".format(
        len(noise_paths), len(os.listdir(DATASET_NOISE_PATH))
    )
)
# Out:
# Found 6 files belonging to 2 directories

# %% [markdown]
# Resample all noise samples to 16000 Hz

# %%
command = (
    "for dir in `ls -1 " + DATASET_NOISE_PATH + "`; do "
    "for file in `ls -1 " + DATASET_NOISE_PATH + "/$dir/*.wav`; do "
    "sample_rate=`ffprobe -hide_banner -loglevel panic -show_streams "
    "$file | grep sample_rate | cut -f2 -d=`; "
    "if [ $sample_rate -ne 16000 ]; then "
    "ffmpeg -hide_banner -loglevel panic -y "
    "-i $file -ar 16000 temp.wav; "
    "mv temp.wav $file; "
    "fi; done; done"
)

os.system(command)

# Split noise into chunks of 16000 each
def load_noise_sample(path):
    sample, sampling_rate = tf.audio.decode_wav(
        tf.io.read_file(path), desired_channels=1
    )
    if sampling_rate == SAMPLING_RATE:
        # Number of slices of 16000 each that can be generated from the noise sample
        slices = int(sample.shape[0] / SAMPLING_RATE)
        sample = tf.split(sample[: slices * SAMPLING_RATE], slices)
        return sample
    else:
        print("Sampling rate for {} is incorrect. Ignoring it".format(path))
        return None


noises = []
for path in noise_paths:
    sample = load_noise_sample(path)
    if sample:
        noises.extend(sample)
noises = tf.stack(noises)

print(
    "{} noise files were split into {} noise samples where each is {} sec. long".format(
        len(noise_paths), noises.shape[0], noises.shape[1] // SAMPLING_RATE
    )
)
# Out:
# 6 noise files were split into 354 noise samples where each is 1 sec. long

# %% [markdown]
# # Dataset generation

# %%
def paths_and_labels_to_dataset(audio_paths, labels):
    """Constructs a dataset of audios and labels."""
    path_ds = tf.data.Dataset.from_tensor_slices(audio_paths)
    audio_ds = path_ds.map(lambda x: path_to_audio(x))
    label_ds = tf.data.Dataset.from_tensor_slices(labels)
    return tf.data.Dataset.zip((audio_ds, label_ds))


def path_to_audio(path):
    """Reads and decodes an audio file."""
    audio = tf.io.read_file(path)
    audio, _ = tf.audio.decode_wav(audio, 1, SAMPLING_RATE)
    return audio


def add_noise(audio, noises=None, scale=0.5):
    if noises is not None:
        # Create a random tensor of the same size as audio ranging from
        # 0 to the number of noise stream samples that we have.
        tf_rnd = tf.random.uniform(
            (tf.shape(audio)[0],), 0, noises.shape[0], dtype=tf.int32
        )
        noise = tf.gather(noises, tf_rnd, axis=0)

        # Get the amplitude proportion between the audio and the noise
        prop = tf.math.reduce_max(audio, axis=1) / tf.math.reduce_max(noise, axis=1)
        prop = tf.repeat(tf.expand_dims(prop, axis=1), tf.shape(audio)[1], axis=1)

        # Adding the rescaled noise to audio
        audio = audio + noise * prop * scale

    return audio


def audio_to_fft(audio):
    # Since tf.signal.fft applies FFT on the innermost dimension,
    # we need to squeeze the dimensions and then expand them again
    # after FFT
    audio = tf.squeeze(audio, axis=-1)
    fft = tf.signal.fft(
        tf.cast(tf.complex(real=audio, imag=tf.zeros_like(audio)), tf.complex64)
    )
    fft = tf.expand_dims(fft, axis=-1)

    # Return the absolute value of the first half of the FFT
    # which represents the positive frequencies
    return tf.math.abs(fft[:, : (audio.shape[1] // 2), :])


# Get the list of audio file paths along with their corresponding labels

class_names = os.listdir(DATASET_AUDIO_PATH)
print("Our class names: {}".format(class_names,))

audio_paths = []
labels = []
for label, name in enumerate(class_names):
    print("Processing speaker {}".format(name,))
    dir_path = Path(DATASET_AUDIO_PATH) / name
    speaker_sample_paths = [
        os.path.join(dir_path, filepath)
        for filepath in os.listdir(dir_path)
        if filepath.endswith(".wav")
    ]
    audio_paths += speaker_sample_paths
    labels += [label] * len(speaker_sample_paths)

print(
    "Found {} files belonging to {} classes.".format(len(audio_paths), len(class_names))
)

# Shuffle
rng = np.random.RandomState(SHUFFLE_SEED)
rng.shuffle(audio_paths)
rng = np.random.RandomState(SHUFFLE_SEED)
rng.shuffle(labels)

# Split into training and validation
num_val_samples = int(VALID_SPLIT * len(audio_paths))
print("Using {} files for training.".format(len(audio_paths) - num_val_samples))
train_audio_paths = audio_paths[:-num_val_samples]
train_labels = labels[:-num_val_samples]

print("Using {} files for validation.".format(num_val_samples))
valid_audio_paths = audio_paths[-num_val_samples:]
valid_labels = labels[-num_val_samples:]

# Create 2 datasets, one for training and the other for validation
train_ds = paths_and_labels_to_dataset(train_audio_paths, train_labels)
train_ds = train_ds.shuffle(buffer_size=BATCH_SIZE * 8, seed=SHUFFLE_SEED).batch(
    BATCH_SIZE
)

valid_ds = paths_and_labels_to_dataset(valid_audio_paths, valid_labels)
valid_ds = valid_ds.shuffle(buffer_size=32 * 8, seed=SHUFFLE_SEED).batch(32)


# Add noise to the training set
train_ds = train_ds.map(
    lambda x, y: (add_noise(x, noises, scale=SCALE), y),
    num_parallel_calls=tf.data.AUTOTUNE,
)

# Transform audio wave to the frequency domain using `audio_to_fft`
train_ds = train_ds.map(
    lambda x, y: (audio_to_fft(x), y), num_parallel_calls=tf.data.AUTOTUNE
)
train_ds = train_ds.prefetch(tf.data.AUTOTUNE)

valid_ds = valid_ds.map(
    lambda x, y: (audio_to_fft(x), y), num_parallel_calls=tf.data.AUTOTUNE
)
valid_ds = valid_ds.prefetch(tf.data.AUTOTUNE)
# Out:
# Our class names: ['Daniel', 'Ed', 'Hom', 'Juan', 'Mike']
# Processing speaker Daniel
# Processing speaker Ed
# Processing speaker Hom
# Processing speaker Juan
# Processing speaker Mike
# Found 1827 files belonging to 5 classes.
# Using 1645 files for training.
# Using 182 files for validation.

# %% [markdown]
# # Model Definition

# %%
def residual_block(x, filters, conv_num=3, activation="relu"):
    # Shortcut
    s = keras.layers.Conv1D(filters, 1, padding="same")(x)
    for i in range(conv_num - 1):
        x = keras.layers.Conv1D(filters, 3, padding="same")(x)
        x = keras.layers.Activation(activation)(x)
    x = keras.layers.Conv1D(filters, 3, padding="same")(x)
    x = keras.layers.Add()([x, s])
    x = keras.layers.Activation(activation)(x)
    return keras.layers.MaxPool1D(pool_size=2, strides=2)(x)


def build_model(input_shape, num_classes):
    inputs = keras.layers.Input(shape=input_shape, name="input")

    x = residual_block(inputs, 16, 2)
    x = residual_block(x, 32, 2)
    x = residual_block(x, 64, 3)
    x = residual_block(x, 128, 3)
    x = residual_block(x, 128, 3)

    x = keras.layers.AveragePooling1D(pool_size=3, strides=3)(x)
    x = keras.layers.Flatten()(x)
    x = keras.layers.Dense(256, activation="relu")(x)
    x = keras.layers.Dense(128, activation="relu")(x)

    outputs = keras.layers.Dense(num_classes, activation="softmax", name="output")(x)

    return keras.models.Model(inputs=inputs, outputs=outputs)


model = build_model((SAMPLING_RATE // 2, 1), len(class_names))

model.summary()

# Compile the model using Adam's default learning rate
model.compile(
    optimizer="Adam", loss="sparse_categorical_crossentropy", metrics=["accuracy"]
)

# Add callbacks:
# 'EarlyStopping' to stop training when the model is not enhancing anymore
# 'ModelCheckPoint' to always keep the model that has the best val_accuracy
model_save_filename = "1DNN_model.h5"

earlystopping_cb = keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True)
mdlcheckpoint_cb = keras.callbacks.ModelCheckpoint(
    model_save_filename, monitor="val_accuracy", save_best_only=True
)
# Out:
# Model: "model_7"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              [(None, 8000, 1)]    0
# __________________________________________________________________________________________________
# conv1d_127 (Conv1D)             (None, 8000, 16)     64          input[0][0]
# __________________________________________________________________________________________________
# activation_91 (Activation)      (None, 8000, 16)     0           conv1d_127[0][0]
# __________________________________________________________________________________________________
# conv1d_128 (Conv1D)             (None, 8000, 16)     784         activation_91[0][0]
# __________________________________________________________________________________________________
# conv1d_126 (Conv1D)             (None, 8000, 16)     32          input[0][0]
# __________________________________________________________________________________________________
# add_35 (Add)                    (None, 8000, 16)     0           conv1d_128[0][0]
#                                                                  conv1d_126[0][0]
# __________________________________________________________________________________________________
# activation_92 (Activation)      (None, 8000, 16)     0           add_35[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_35 (MaxPooling1D) (None, 4000, 16)     0           activation_92[0][0]
# __________________________________________________________________________________________________
# conv1d_130 (Conv1D)             (None, 4000, 32)     1568        max_pooling1d_35[0][0]
# __________________________________________________________________________________________________
# activation_93 (Activation)      (None, 4000, 32)     0           conv1d_130[0][0]
# __________________________________________________________________________________________________
# conv1d_131 (Conv1D)             (None, 4000, 32)     3104        activation_93[0][0]
# __________________________________________________________________________________________________
# conv1d_129 (Conv1D)             (None, 4000, 32)     544         max_pooling1d_35[0][0]
# __________________________________________________________________________________________________
# add_36 (Add)                    (None, 4000, 32)     0           conv1d_131[0][0]
#                                                                  conv1d_129[0][0]
# __________________________________________________________________________________________________
# activation_94 (Activation)      (None, 4000, 32)     0           add_36[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_36 (MaxPooling1D) (None, 2000, 32)     0           activation_94[0][0]
# __________________________________________________________________________________________________
# conv1d_133 (Conv1D)             (None, 2000, 64)     6208        max_pooling1d_36[0][0]
# __________________________________________________________________________________________________
# activation_95 (Activation)      (None, 2000, 64)     0           conv1d_133[0][0]
# __________________________________________________________________________________________________
# conv1d_134 (Conv1D)             (None, 2000, 64)     12352       activation_95[0][0]
# __________________________________________________________________________________________________
# activation_96 (Activation)      (None, 2000, 64)     0           conv1d_134[0][0]
# __________________________________________________________________________________________________
# conv1d_135 (Conv1D)             (None, 2000, 64)     12352       activation_96[0][0]
# __________________________________________________________________________________________________
# conv1d_132 (Conv1D)             (None, 2000, 64)     2112        max_pooling1d_36[0][0]
# __________________________________________________________________________________________________
# add_37 (Add)                    (None, 2000, 64)     0           conv1d_135[0][0]
#                                                                  conv1d_132[0][0]
# __________________________________________________________________________________________________
# activation_97 (Activation)      (None, 2000, 64)     0           add_37[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_37 (MaxPooling1D) (None, 1000, 64)     0           activation_97[0][0]
# __________________________________________________________________________________________________
# conv1d_137 (Conv1D)             (None, 1000, 128)    24704       max_pooling1d_37[0][0]
# __________________________________________________________________________________________________
# activation_98 (Activation)      (None, 1000, 128)    0           conv1d_137[0][0]
# __________________________________________________________________________________________________
# conv1d_138 (Conv1D)             (None, 1000, 128)    49280       activation_98[0][0]
# __________________________________________________________________________________________________
# activation_99 (Activation)      (None, 1000, 128)    0           conv1d_138[0][0]
# __________________________________________________________________________________________________
# conv1d_139 (Conv1D)             (None, 1000, 128)    49280       activation_99[0][0]
# __________________________________________________________________________________________________
# conv1d_136 (Conv1D)             (None, 1000, 128)    8320        max_pooling1d_37[0][0]
# __________________________________________________________________________________________________
# add_38 (Add)                    (None, 1000, 128)    0           conv1d_139[0][0]
#                                                                  conv1d_136[0][0]
# __________________________________________________________________________________________________
# activation_100 (Activation)     (None, 1000, 128)    0           add_38[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_38 (MaxPooling1D) (None, 500, 128)     0           activation_100[0][0]
# __________________________________________________________________________________________________
# conv1d_141 (Conv1D)             (None, 500, 128)     49280       max_pooling1d_38[0][0]
# __________________________________________________________________________________________________
# activation_101 (Activation)     (None, 500, 128)     0           conv1d_141[0][0]
# __________________________________________________________________________________________________
# conv1d_142 (Conv1D)             (None, 500, 128)     49280       activation_101[0][0]
# __________________________________________________________________________________________________
# activation_102 (Activation)     (None, 500, 128)     0           conv1d_142[0][0]
# __________________________________________________________________________________________________
# conv1d_143 (Conv1D)             (None, 500, 128)     49280       activation_102[0][0]
# __________________________________________________________________________________________________
# conv1d_140 (Conv1D)             (None, 500, 128)     16512       max_pooling1d_38[0][0]
# __________________________________________________________________________________________________
# add_39 (Add)                    (None, 500, 128)     0           conv1d_143[0][0]
#                                                                  conv1d_140[0][0]
# __________________________________________________________________________________________________
# activation_103 (Activation)     (None, 500, 128)     0           add_39[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_39 (MaxPooling1D) (None, 250, 128)     0           activation_103[0][0]
# __________________________________________________________________________________________________
# average_pooling1d_7 (AveragePoo (None, 83, 128)      0           max_pooling1d_39[0][0]
# __________________________________________________________________________________________________
# flatten_7 (Flatten)             (None, 10624)        0           average_pooling1d_7[0][0]
# __________________________________________________________________________________________________
# dense_14 (Dense)                (None, 256)          2720000     flatten_7[0][0]
# __________________________________________________________________________________________________
# dense_15 (Dense)                (None, 128)          32896       dense_14[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 7)            903         dense_15[0][0]
# ==================================================================================================
# Total params: 3,088,855
# Trainable params: 3,088,855
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# # Training

# %%
history = model.fit(
    train_ds,
    epochs=EPOCHS,
    validation_data=valid_ds,
    callbacks=[earlystopping_cb, mdlcheckpoint_cb],
)
# Out:
# Epoch 1/100
# 13/13 [==============================] - 5s 219ms/step - loss: 1.5409 - accuracy: 0.3319 - val_loss: 1.1016 - val_accuracy: 0.6374
# Epoch 2/100
# 13/13 [==============================] - 2s 137ms/step - loss: 0.8018 - accuracy: 0.7307 - val_loss: 0.4848 - val_accuracy: 0.8407
# Epoch 3/100
# 13/13 [==============================] - 2s 138ms/step - loss: 0.4932 - accuracy: 0.8389 - val_loss: 0.3039 - val_accuracy: 0.8846
# Epoch 4/100
# 13/13 [==============================] - 2s 139ms/step - loss: 0.3789 - accuracy: 0.8711 - val_loss: 0.2869 - val_accuracy: 0.8956
# Epoch 5/100
# 13/13 [==============================] - 2s 139ms/step - loss: 0.3310 - accuracy: 0.8997 - val_loss: 0.2206 - val_accuracy: 0.9176
# Epoch 6/100
# 13/13 [==============================] - 2s 137ms/step - loss: 0.3294 - accuracy: 0.8881 - val_loss: 0.2224 - val_accuracy: 0.9341
# Epoch 7/100
# 13/13 [==============================] - 2s 137ms/step - loss: 0.2507 - accuracy: 0.9185 - val_loss: 0.1305 - val_accuracy: 0.9725
# Epoch 8/100
# 13/13 [==============================] - 2s 137ms/step - loss: 0.1983 - accuracy: 0.9325 - val_loss: 0.1218 - val_accuracy: 0.9725
# Epoch 9/100
# 13/13 [==============================] - 2s 137ms/step - loss: 0.1803 - accuracy: 0.9410 - val_loss: 0.1206 - val_accuracy: 0.9670
# Epoch 10/100
# 13/13 [==============================] - 2s 137ms/step - loss: 0.1710 - accuracy: 0.9386 - val_loss: 0.1251 - val_accuracy: 0.9560
# Epoch 11/100
# 13/13 [==============================] - 2s 137ms/step - loss: 0.1460 - accuracy: 0.9520 - val_loss: 0.1099 - val_accuracy: 0.9670
# Epoch 12/100
# 13/13 [==============================] - 2s 137ms/step - loss: 0.1314 - accuracy: 0.9617 - val_loss: 0.1028 - val_accuracy: 0.9670
# Epoch 13/100
# 13/13 [==============================] - 2s 137ms/step - loss: 0.1535 - accuracy: 0.9514 - val_loss: 0.1692 - val_accuracy: 0.9560
# Epoch 14/100
# 13/13 [==============================] - 2s 137ms/step - loss: 0.1720 - accuracy: 0.9404 - val_loss: 0.1586 - val_accuracy: 0.9451
# Epoch 15/100
# 13/13 [==============================] - 2s 140ms/step - loss: 0.1618 - accuracy: 0.9471 - val_loss: 0.0880 - val_accuracy: 0.9725
# Epoch 16/100
# 13/13 [==============================] - 2s 137ms/step - loss: 0.1023 - accuracy: 0.9690 - val_loss: 0.0869 - val_accuracy: 0.9725
# Epoch 17/100
# 13/13 [==============================] - 2s 137ms/step - loss: 0.0769 - accuracy: 0.9769 - val_loss: 0.1129 - val_accuracy: 0.9670
# Epoch 18/100
# 13/13 [==============================] - 2s 138ms/step - loss: 0.0972 - accuracy: 0.9702 - val_loss: 0.1145 - val_accuracy: 0.9615
# Epoch 19/100
# 13/13 [==============================] - 2s 138ms/step - loss: 0.1063 - accuracy: 0.9611 - val_loss: 0.0619 - val_accuracy: 0.9945
# Epoch 20/100
# 13/13 [==============================] - 2s 139ms/step - loss: 0.1324 - accuracy: 0.9623 - val_loss: 0.0645 - val_accuracy: 0.9945
# Epoch 21/100
# 13/13 [==============================] - 2s 137ms/step - loss: 0.1244 - accuracy: 0.9556 - val_loss: 0.1237 - val_accuracy: 0.9615
# Epoch 22/100
# 13/13 [==============================] - 2s 138ms/step - loss: 0.0876 - accuracy: 0.9757 - val_loss: 0.0528 - val_accuracy: 0.9835
# Epoch 23/100
# 13/13 [==============================] - 2s 138ms/step - loss: 0.0639 - accuracy: 0.9818 - val_loss: 0.0566 - val_accuracy: 0.9945
# Epoch 24/100
# 13/13 [==============================] - 2s 137ms/step - loss: 0.0481 - accuracy: 0.9842 - val_loss: 0.0429 - val_accuracy: 0.9945
# Epoch 25/100
# 13/13 [==============================] - 2s 137ms/step - loss: 0.0389 - accuracy: 0.9866 - val_loss: 0.1120 - val_accuracy: 0.9670
# Epoch 26/100
# 13/13 [==============================] - 2s 140ms/step - loss: 0.0272 - accuracy: 0.9927 - val_loss: 0.0510 - val_accuracy: 0.9945
# Epoch 27/100
# 13/13 [==============================] - 2s 137ms/step - loss: 0.0335 - accuracy: 0.9884 - val_loss: 0.0610 - val_accuracy: 0.9835
# Epoch 28/100
# 13/13 [==============================] - 2s 137ms/step - loss: 0.0283 - accuracy: 0.9897 - val_loss: 0.0639 - val_accuracy: 0.9835
# Epoch 29/100
# 13/13 [==============================] - 2s 137ms/step - loss: 0.0578 - accuracy: 0.9830 - val_loss: 0.1163 - val_accuracy: 0.9615
# Epoch 30/100
# 13/13 [==============================] - 2s 137ms/step - loss: 0.0937 - accuracy: 0.9623 - val_loss: 0.0688 - val_accuracy: 0.9835
# Epoch 31/100
# 13/13 [==============================] - 2s 137ms/step - loss: 0.0650 - accuracy: 0.9781 - val_loss: 0.0599 - val_accuracy: 0.9890
# Epoch 32/100
# 13/13 [==============================] - 2s 138ms/step - loss: 0.0496 - accuracy: 0.9854 - val_loss: 0.0700 - val_accuracy: 0.9780
# Epoch 33/100
# 13/13 [==============================] - 2s 137ms/step - loss: 0.0709 - accuracy: 0.9787 - val_loss: 0.0681 - val_accuracy: 0.9835
# Epoch 34/100
# 13/13 [==============================] - 2s 137ms/step - loss: 0.0439 - accuracy: 0.9836 - val_loss: 0.0981 - val_accuracy: 0.9725

# %% [markdown]
# # Evaluation

# %%
print(model.evaluate(valid_ds))
# Out:
# 6/6 [==============================] - 0s 50ms/step - loss: 0.0429 - accuracy: 0.9945
# [0.04287491366267204, 0.9945054650306702]

# %%
_, accuracy = model.evaluate(valid_ds)
print('Accuracy: %.1f' % (accuracy*100))
# Out:
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0429 - accuracy: 0.9945
# Accuracy: 99.5

# %%
# plot training history
# %matplotlib inline 
from matplotlib import pyplot
pyplot.plot(history.history['loss'], label='loss')
pyplot.plot(history.history['val_loss'], label='val_loss')
pyplot.plot(history.history['accuracy'], label='accuracy')
pyplot.plot(history.history['val_accuracy'], label='val_accuracy')
pyplot.legend()
#plt.title('model accuracy')
pyplot.xlabel('Epoch')
pyplot.ylabel('Loss/Accuracy')
pyplot.show()

# %% [markdown]
# # Demonstration
# Let's take some samples and:
#
# - Predict the speaker
# - Compare the prediction with the real speaker
# - Listen to the audio to see that despite the samples being noisy, the model is still pretty accurate

# %%
SAMPLES_TO_DISPLAY = 10

test_ds = paths_and_labels_to_dataset(valid_audio_paths, valid_labels)
test_ds = test_ds.shuffle(buffer_size=BATCH_SIZE * 8, seed=SHUFFLE_SEED).batch(
    BATCH_SIZE
)

test_ds = test_ds.map(lambda x, y: (add_noise(x, noises, scale=SCALE), y))

for audios, labels in test_ds.take(1):
    # Get the signal FFT
    ffts = audio_to_fft(audios)
    # Predict
    y_pred = model.predict(ffts)
    # Take random samples
    rnd = np.random.randint(0, BATCH_SIZE, SAMPLES_TO_DISPLAY)
    audios = audios.numpy()[rnd, :, :]
    labels = labels.numpy()[rnd]
    y_pred = np.argmax(y_pred, axis=-1)[rnd]

    for index in range(SAMPLES_TO_DISPLAY):
        # For every sample, print the true and predicted label
        # as well as run the voice with the noise
        print(
            "Speaker: {} - Predicted: {}".format(
                class_names[labels[index]],
                class_names[y_pred[index]],
            )
        )
        display(Audio(audios[index, :, :].squeeze(), rate=SAMPLING_RATE))
# Out:
# Speaker: Daniel - Predicted: Daniel
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Speaker: Ed - Predicted: Ed
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Speaker: Juan - Predicted: Juan
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Speaker: Mike - Predicted: Mike
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Speaker: Daniel - Predicted: Daniel
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Speaker: Hom - Predicted: Hom
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Speaker: Mike - Predicted: Mike
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Speaker: Daniel - Predicted: Daniel
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Speaker: Hom - Predicted: Hom
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Speaker: Mike - Predicted: Mike
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
model.save("Speaker_Recognition_Model")

# %%
model = keras.models.load_model("Speaker_Recognition_Model")

# %%
keras.utils.plot_model(model, show_shapes=True)

# %% [markdown]
# # Model 2

# %%
def residual_block(x, filters, conv_num=3, activation="relu"):
    # Shortcut
    s = keras.layers.Conv1D(filters, 1, padding="same")(x)
    for i in range(conv_num - 1):
        x = keras.layers.Conv1D(filters, 3, padding="same")(x)
        x = keras.layers.Activation(activation)(x)
    x = keras.layers.Conv1D(filters, 3, padding="same")(x)
    x = keras.layers.Add()([x, s])
    x = keras.layers.Activation(activation)(x)
    return keras.layers.MaxPool1D(pool_size=2, strides=2)(x)


def build_model(input_shape, num_classes):
    inputs = keras.layers.Input(shape=input_shape, name="input")

    x = residual_block(inputs, 18, 2)
    x = residual_block(x, 34, 2)
    x = residual_block(x, 68, 3)
    x = residual_block(x, 136, 3)
    x = residual_block(x, 136, 3)

    x = keras.layers.AveragePooling1D(pool_size=3, strides=3)(x)
    x = keras.layers.Flatten()(x)
    x = keras.layers.Dense(308, activation="relu")(x)
    x = keras.layers.Dense(154, activation="relu")(x)

    outputs = keras.layers.Dense(num_classes, activation="softmax", name="output")(x)

    return keras.models.Model(inputs=inputs, outputs=outputs)


model = build_model((SAMPLING_RATE // 2, 1), len(class_names))

model.summary()

# Compile the model using Adam's default learning rate
model.compile(
    optimizer="Adam", loss="sparse_categorical_crossentropy", metrics=["accuracy"]
)

# Add callbacks:
# 'EarlyStopping' to stop training when the model is not enhancing anymore
# 'ModelCheckPoint' to always keep the model that has the best val_accuracy
model_save_filename = "model.h5"

earlystopping_cb = keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True)
mdlcheckpoint_cb = keras.callbacks.ModelCheckpoint(
    model_save_filename, monitor="val_accuracy", save_best_only=True
)
# Out:
# Model: "model_8"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              [(None, 8000, 1)]    0
# __________________________________________________________________________________________________
# conv1d_145 (Conv1D)             (None, 8000, 18)     72          input[0][0]
# __________________________________________________________________________________________________
# activation_104 (Activation)     (None, 8000, 18)     0           conv1d_145[0][0]
# __________________________________________________________________________________________________
# conv1d_146 (Conv1D)             (None, 8000, 18)     990         activation_104[0][0]
# __________________________________________________________________________________________________
# conv1d_144 (Conv1D)             (None, 8000, 18)     36          input[0][0]
# __________________________________________________________________________________________________
# add_40 (Add)                    (None, 8000, 18)     0           conv1d_146[0][0]
#                                                                  conv1d_144[0][0]
# __________________________________________________________________________________________________
# activation_105 (Activation)     (None, 8000, 18)     0           add_40[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_40 (MaxPooling1D) (None, 4000, 18)     0           activation_105[0][0]
# __________________________________________________________________________________________________
# conv1d_148 (Conv1D)             (None, 4000, 34)     1870        max_pooling1d_40[0][0]
# __________________________________________________________________________________________________
# activation_106 (Activation)     (None, 4000, 34)     0           conv1d_148[0][0]
# __________________________________________________________________________________________________
# conv1d_149 (Conv1D)             (None, 4000, 34)     3502        activation_106[0][0]
# __________________________________________________________________________________________________
# conv1d_147 (Conv1D)             (None, 4000, 34)     646         max_pooling1d_40[0][0]
# __________________________________________________________________________________________________
# add_41 (Add)                    (None, 4000, 34)     0           conv1d_149[0][0]
#                                                                  conv1d_147[0][0]
# __________________________________________________________________________________________________
# activation_107 (Activation)     (None, 4000, 34)     0           add_41[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_41 (MaxPooling1D) (None, 2000, 34)     0           activation_107[0][0]
# __________________________________________________________________________________________________
# conv1d_151 (Conv1D)             (None, 2000, 68)     7004        max_pooling1d_41[0][0]
# __________________________________________________________________________________________________
# activation_108 (Activation)     (None, 2000, 68)     0           conv1d_151[0][0]
# __________________________________________________________________________________________________
# conv1d_152 (Conv1D)             (None, 2000, 68)     13940       activation_108[0][0]
# __________________________________________________________________________________________________
# activation_109 (Activation)     (None, 2000, 68)     0           conv1d_152[0][0]
# __________________________________________________________________________________________________
# conv1d_153 (Conv1D)             (None, 2000, 68)     13940       activation_109[0][0]
# __________________________________________________________________________________________________
# conv1d_150 (Conv1D)             (None, 2000, 68)     2380        max_pooling1d_41[0][0]
# __________________________________________________________________________________________________
# add_42 (Add)                    (None, 2000, 68)     0           conv1d_153[0][0]
#                                                                  conv1d_150[0][0]
# __________________________________________________________________________________________________
# activation_110 (Activation)     (None, 2000, 68)     0           add_42[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_42 (MaxPooling1D) (None, 1000, 68)     0           activation_110[0][0]
# __________________________________________________________________________________________________
# conv1d_155 (Conv1D)             (None, 1000, 136)    27880       max_pooling1d_42[0][0]
# __________________________________________________________________________________________________
# activation_111 (Activation)     (None, 1000, 136)    0           conv1d_155[0][0]
# __________________________________________________________________________________________________
# conv1d_156 (Conv1D)             (None, 1000, 136)    55624       activation_111[0][0]
# __________________________________________________________________________________________________
# activation_112 (Activation)     (None, 1000, 136)    0           conv1d_156[0][0]
# __________________________________________________________________________________________________
# conv1d_157 (Conv1D)             (None, 1000, 136)    55624       activation_112[0][0]
# __________________________________________________________________________________________________
# conv1d_154 (Conv1D)             (None, 1000, 136)    9384        max_pooling1d_42[0][0]
# __________________________________________________________________________________________________
# add_43 (Add)                    (None, 1000, 136)    0           conv1d_157[0][0]
#                                                                  conv1d_154[0][0]
# __________________________________________________________________________________________________
# activation_113 (Activation)     (None, 1000, 136)    0           add_43[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_43 (MaxPooling1D) (None, 500, 136)     0           activation_113[0][0]
# __________________________________________________________________________________________________
# conv1d_159 (Conv1D)             (None, 500, 136)     55624       max_pooling1d_43[0][0]
# __________________________________________________________________________________________________
# activation_114 (Activation)     (None, 500, 136)     0           conv1d_159[0][0]
# __________________________________________________________________________________________________
# conv1d_160 (Conv1D)             (None, 500, 136)     55624       activation_114[0][0]
# __________________________________________________________________________________________________
# activation_115 (Activation)     (None, 500, 136)     0           conv1d_160[0][0]
# __________________________________________________________________________________________________
# conv1d_161 (Conv1D)             (None, 500, 136)     55624       activation_115[0][0]
# __________________________________________________________________________________________________
# conv1d_158 (Conv1D)             (None, 500, 136)     18632       max_pooling1d_43[0][0]
# __________________________________________________________________________________________________
# add_44 (Add)                    (None, 500, 136)     0           conv1d_161[0][0]
#                                                                  conv1d_158[0][0]
# __________________________________________________________________________________________________
# activation_116 (Activation)     (None, 500, 136)     0           add_44[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_44 (MaxPooling1D) (None, 250, 136)     0           activation_116[0][0]
# __________________________________________________________________________________________________
# average_pooling1d_8 (AveragePoo (None, 83, 136)      0           max_pooling1d_44[0][0]
# __________________________________________________________________________________________________
# flatten_8 (Flatten)             (None, 11288)        0           average_pooling1d_8[0][0]
# __________________________________________________________________________________________________
# dense_16 (Dense)                (None, 308)          3477012     flatten_8[0][0]
# __________________________________________________________________________________________________
# dense_17 (Dense)                (None, 154)          47586       dense_16[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 5)            775         dense_17[0][0]
# ==================================================================================================
# Total params: 3,903,769
# Trainable params: 3,903,769
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
history = model.fit(
    train_ds,
    epochs=EPOCHS,
    validation_data=valid_ds,
    callbacks=[earlystopping_cb, mdlcheckpoint_cb],
)
# Out:
# Epoch 1/100
# 13/13 [==============================] - 7s 307ms/step - loss: 1.6819 - accuracy: 0.3198 - val_loss: 0.9934 - val_accuracy: 0.6758
# Epoch 2/100
# 13/13 [==============================] - 3s 185ms/step - loss: 0.8226 - accuracy: 0.7222 - val_loss: 0.4472 - val_accuracy: 0.8681
# Epoch 3/100
# 13/13 [==============================] - 3s 185ms/step - loss: 0.5211 - accuracy: 0.8249 - val_loss: 0.3923 - val_accuracy: 0.8791
# Epoch 4/100
# 13/13 [==============================] - 3s 185ms/step - loss: 0.4297 - accuracy: 0.8571 - val_loss: 0.3304 - val_accuracy: 0.9066
# Epoch 5/100
# 13/13 [==============================] - 3s 185ms/step - loss: 0.3163 - accuracy: 0.8930 - val_loss: 0.2148 - val_accuracy: 0.9231
# Epoch 6/100
# 13/13 [==============================] - 3s 185ms/step - loss: 0.2403 - accuracy: 0.9173 - val_loss: 0.1368 - val_accuracy: 0.9560
# Epoch 7/100
# 13/13 [==============================] - 3s 185ms/step - loss: 0.2612 - accuracy: 0.9137 - val_loss: 0.1451 - val_accuracy: 0.9725
# Epoch 8/100
# 13/13 [==============================] - 3s 185ms/step - loss: 0.2385 - accuracy: 0.9210 - val_loss: 0.1242 - val_accuracy: 0.9560
# Epoch 9/100
# 13/13 [==============================] - 3s 185ms/step - loss: 0.1985 - accuracy: 0.9283 - val_loss: 0.1091 - val_accuracy: 0.9670
# Epoch 10/100
# 13/13 [==============================] - 3s 186ms/step - loss: 0.2062 - accuracy: 0.9252 - val_loss: 0.1324 - val_accuracy: 0.9615
# Epoch 11/100
# 13/13 [==============================] - 3s 185ms/step - loss: 0.1663 - accuracy: 0.9416 - val_loss: 0.1618 - val_accuracy: 0.9451
# Epoch 12/100
# 13/13 [==============================] - 3s 185ms/step - loss: 0.1298 - accuracy: 0.9605 - val_loss: 0.0884 - val_accuracy: 0.9780
# Epoch 13/100
# 13/13 [==============================] - 3s 185ms/step - loss: 0.1359 - accuracy: 0.9544 - val_loss: 0.1576 - val_accuracy: 0.9396
# Epoch 14/100
# 13/13 [==============================] - 3s 185ms/step - loss: 0.1358 - accuracy: 0.9495 - val_loss: 0.1141 - val_accuracy: 0.9451
# Epoch 15/100
# 13/13 [==============================] - 3s 186ms/step - loss: 0.1169 - accuracy: 0.9647 - val_loss: 0.0832 - val_accuracy: 0.9780
# Epoch 16/100
# 13/13 [==============================] - 3s 185ms/step - loss: 0.1140 - accuracy: 0.9617 - val_loss: 0.0800 - val_accuracy: 0.9725
# Epoch 17/100
# 13/13 [==============================] - 3s 186ms/step - loss: 0.1147 - accuracy: 0.9587 - val_loss: 0.0764 - val_accuracy: 0.9780
# Epoch 18/100
# 13/13 [==============================] - 3s 185ms/step - loss: 0.0918 - accuracy: 0.9696 - val_loss: 0.0813 - val_accuracy: 0.9780
# Epoch 19/100
# 13/13 [==============================] - 3s 186ms/step - loss: 0.0795 - accuracy: 0.9757 - val_loss: 0.0717 - val_accuracy: 0.9780
# Epoch 20/100
# 13/13 [==============================] - 3s 185ms/step - loss: 0.0670 - accuracy: 0.9775 - val_loss: 0.0714 - val_accuracy: 0.9780
# Epoch 21/100
# 13/13 [==============================] - 3s 186ms/step - loss: 0.0519 - accuracy: 0.9866 - val_loss: 0.0777 - val_accuracy: 0.9780
# Epoch 22/100
# 13/13 [==============================] - 3s 185ms/step - loss: 0.0545 - accuracy: 0.9781 - val_loss: 0.0349 - val_accuracy: 0.9890
# Epoch 23/100
# 13/13 [==============================] - 3s 185ms/step - loss: 0.1123 - accuracy: 0.9720 - val_loss: 0.0454 - val_accuracy: 0.9890
# Epoch 24/100
# 13/13 [==============================] - 3s 185ms/step - loss: 0.0578 - accuracy: 0.9805 - val_loss: 0.0360 - val_accuracy: 0.9945
# Epoch 25/100
# 13/13 [==============================] - 3s 185ms/step - loss: 0.0501 - accuracy: 0.9787 - val_loss: 0.0468 - val_accuracy: 0.9890
# Epoch 26/100
# 13/13 [==============================] - 3s 185ms/step - loss: 0.0530 - accuracy: 0.9824 - val_loss: 0.0700 - val_accuracy: 0.9835
# Epoch 27/100
# 13/13 [==============================] - 3s 185ms/step - loss: 0.0870 - accuracy: 0.9763 - val_loss: 0.0429 - val_accuracy: 0.9780
# Epoch 28/100
# 13/13 [==============================] - 3s 185ms/step - loss: 0.0610 - accuracy: 0.9775 - val_loss: 0.0384 - val_accuracy: 0.9945
# Epoch 29/100
# 13/13 [==============================] - 3s 186ms/step - loss: 0.0793 - accuracy: 0.9757 - val_loss: 0.0537 - val_accuracy: 0.9835
# Epoch 30/100
# 13/13 [==============================] - 3s 185ms/step - loss: 0.0343 - accuracy: 0.9891 - val_loss: 0.0422 - val_accuracy: 0.9835
# Epoch 31/100
# 13/13 [==============================] - 3s 186ms/step - loss: 0.0448 - accuracy: 0.9878 - val_loss: 0.0200 - val_accuracy: 0.9945
# Epoch 32/100
# 13/13 [==============================] - 3s 185ms/step - loss: 0.0516 - accuracy: 0.9830 - val_loss: 0.0792 - val_accuracy: 0.9780
# Epoch 33/100
# 13/13 [==============================] - 3s 186ms/step - loss: 0.0285 - accuracy: 0.9927 - val_loss: 0.0420 - val_accuracy: 0.9945
# Epoch 34/100
# 13/13 [==============================] - 3s 186ms/step - loss: 0.0439 - accuracy: 0.9866 - val_loss: 0.0493 - val_accuracy: 0.9945
# Epoch 35/100
# 13/13 [==============================] - 3s 186ms/step - loss: 0.0404 - accuracy: 0.9884 - val_loss: 0.0447 - val_accuracy: 0.9945
# Epoch 36/100
# 13/13 [==============================] - 3s 185ms/step - loss: 0.0587 - accuracy: 0.9733 - val_loss: 0.0760 - val_accuracy: 0.9835
# Epoch 37/100
# 13/13 [==============================] - 3s 185ms/step - loss: 0.0292 - accuracy: 0.9927 - val_loss: 0.0671 - val_accuracy: 0.9835
# Epoch 38/100
# 13/13 [==============================] - 3s 186ms/step - loss: 0.0239 - accuracy: 0.9951 - val_loss: 0.0581 - val_accuracy: 0.9890
# Epoch 39/100
# 13/13 [==============================] - 3s 185ms/step - loss: 0.0179 - accuracy: 0.9951 - val_loss: 0.0727 - val_accuracy: 0.9835
# Epoch 40/100
# 13/13 [==============================] - 3s 187ms/step - loss: 0.0192 - accuracy: 0.9939 - val_loss: 0.0399 - val_accuracy: 0.9945
# Epoch 41/100
# 13/13 [==============================] - 3s 186ms/step - loss: 0.0233 - accuracy: 0.9927 - val_loss: 0.0649 - val_accuracy: 0.9890

# %%
print(model.evaluate(valid_ds))
# Out:
# 6/6 [==============================] - 0s 38ms/step - loss: 0.0200 - accuracy: 0.9945
# [0.019981205463409424, 0.9945054650306702]

# %%
_, accuracy = model.evaluate(valid_ds)
print('Accuracy: %.1f' % (accuracy*100))
# Out:
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0200 - accuracy: 0.9945
# Accuracy: 99.5

# %%
# plot training history
# %matplotlib inline 
from matplotlib import pyplot
pyplot.plot(history.history['loss'], label='loss')
pyplot.plot(history.history['val_loss'], label='val_loss')
pyplot.plot(history.history['accuracy'], label='accuracy')
pyplot.plot(history.history['val_accuracy'], label='val_accuracy')
pyplot.legend()
#plt.title('model accuracy')
pyplot.xlabel('Epoch')
pyplot.ylabel('Loss/Accuracy')
pyplot.show()
